# %% [markdown]
# <a href="https://colab.research.google.com/github/Vaibhavs10/notebooks/blob/main/transformers_autoawq_colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -U -q transformers https://github.com/casper-hansen/AutoAWQ/releases/download/v0.1.6/autoawq-0.1.6+cu118-cp310-cp310-linux_x86_64.whl
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 20.0/20.0 MB 62.4 MB/s eta 0:00:00

# %%
from transformers import AutoModelForCausalLM, AutoTokenizer

model_id = "TheBloke/zephyr-7B-beta-AWQ"
tokenizer = AutoTokenizer.from_pretrained(model_id)
model = AutoModelForCausalLM.from_pretrained(model_id, device_map="cuda:0")
# Out:
# (…)a-AWQ/resolve/main/tokenizer_config.json:   0%|          | 0.00/1.43k [00:00<?, ?B/s]
# tokenizer.model:   0%|          | 0.00/493k [00:00<?, ?B/s]
# (…)-7B-beta-AWQ/resolve/main/tokenizer.json:   0%|          | 0.00/1.80M [00:00<?, ?B/s]
# (…)AWQ/resolve/main/special_tokens_map.json:   0%|          | 0.00/168 [00:00<?, ?B/s]
# (…)hyr-7B-beta-AWQ/resolve/main/config.json:   0%|          | 0.00/828 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/4.15G [00:00<?, ?B/s]
# (…)-AWQ/resolve/main/generation_config.json:   0%|          | 0.00/116 [00:00<?, ?B/s]

# %%
prompt = "Tell me a lame joke about Machine Learning Engineers?"

prompt_template = f'''<|system|>
</s>
<|user|>
{prompt}</s>
<|assistant|>
'''

# %%
input_ids = tokenizer(prompt_template, return_tensors="pt").to("cuda:0")

# %%
output = model.generate(**input_ids, do_sample=True, max_new_tokens=300)
# Out:
# /usr/local/lib/python3.10/dist-packages/transformers/generation/utils.py:1473: UserWarning: You have modified the pretrained model configuration to control generation. This is a deprecated strategy to control generation and will be removed soon, in a future version. Please use and modify the model generation configuration (see https://huggingface.co/docs/transformers/generation_strategies#default-text-generation-configuration )
#   warnings.warn(

# %%
print(tokenizer.decode(output[0], skip_special_tokens=True))
# Out:
# <|system|>
#
# <|user|>
# Tell me a lame joke about Machine Learning Engineers?
# <|assistant|>
# Why did the Machine Learning Engineer bring a calculator to a party?
#
# To impress the other guests with his high accuracy in predicting the number of drinks needed.
#
# But sadly, no one at the party seemed to find him as entertaining as his jokes about overfitting and undergeneralizing.
#
# (Not really a joke, but perhaps a pun.)
